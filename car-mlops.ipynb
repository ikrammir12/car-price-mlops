# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/content/CAR DETAILS FROM CAR DEKHO.csv')

# %%
df.head()

# %%
df.isnull().sum()

# %%
df.duplicated().sum()

# %%
df['name'].unique()

# %%
df['year'].unique()

# %%
df.head()

# %%
df['fuel'].unique()
df = pd.get_dummies(df,columns=['fuel'],prefix='Fuel',drop_first=True)

# %%
df.head()

# %%
df['transmission'].unique()

# %%
df['transmission'].replace({'Manual':0,"Automatic":1},inplace=True)

# %%
df.head()

# %%
df['owner'].unique()

# %%
df=pd.get_dummies(df,columns=['owner'],prefix='owmer',drop_first=True)

# %%
df['seller_type'].unique()

# %%
df=pd.get_dummies(df,columns=['seller_type'],prefix='seller',drop_first=True)

# %%
df.head()

# %%
df.head()

# %%
df.drop(columns='name',inplace=True)

# %%
df.head()
